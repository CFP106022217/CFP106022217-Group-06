# %%
import numpy as np

def rect(x, B):
    
    B = int(B)
    x = int(x)
    
    high = np.ones(B)
    low1 = np.zeros(int(x/2 - B/2))    
    x1 = np.append(low1, high)
    rect = np.append(x1, low1)
    
    if x > len(rect):
        rect = np.append(rect, 0)
    elif x < len(rect):
        rect = rect[:-1]

    return rect

# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# constants and x array
pi = np.pi
length = 2000
x = np.linspace(-1, 1, length)

# create figure and axes 
fig, (ax1) = plt.subplots(1, figsize=(6, 3))

# creating our line objects for the plots
sinc, = ax1.plot(x, np.sin(x), '-b')

def animate(B):
    
    # create our sinc object
    F = (B / length) * np.sin(x * B / 2) / (x * B / 2)
    sinc.set_ydata(F)
    
    # adjust the sinc plot height in a loop
    ax1.set_ylim(np.min(F), np.max(F))
    
    
def init():
    
    ax1.set_xlim(-0.25, 0.25)
    ax1.axhline(0, color='black', lw=1)
    plt.rcParams.update({'font.size':14})
    
    return sinc, 

# the FuncAnimation function iterates through our animate function using the steps array
step = 10
steps = np.append(np.arange(10, 1000, step), np.arange(1000, 10, -1 * step))
ani = FuncAnimation(fig, animate, steps, init_func=init, interval=50, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
import numpy as np
import scipy as sp
import math

E0, k, w ,w0, r = 1, 1, 1, 1, 0.3
q, m = 1.6* 10**-19 ,  9.11* 10**-31
epsilon0 = 8.85*10**-12
c = 3*10**8
N = 10**4
kapa = 0.5*N* q**2 * w**2 /(m*epsilon0*c)

def rect(z, t):
    
    t = int(t)
    z = int(z)
    
    high = np.ones(t)
    low1 = np.zeros(int(z/2 - t/2))    
    z1 = np.append(low1, high)
    rect = np.append(z1, low1)
    
    if x > len(rect):
        rect = np.append(rect, 0)
    elif x < len(rect):
        rect = rect[:-1]

    return rect

# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# constants and x array
pi = np.pi
length = 100000
z = np.linspace(0, 10000, length)

# create figure and axes 
fig, (az1) = plt.subplots(1, figsize=(6, 3))

# creating our line objects for the plots
sinc, = az1.plot(z, np.sin(z), '-b')

def animate(t):
    
    # create our sinc object
    E = np.real(E0 * np.exp(-kapa*z) * np.exp(1j*(k*z-w*t)))
    x0 = E*q/m/(w0**2 - w**2 - 1j*r*w)
    x = np.real(x0 * np.exp(-1j*w*t))
    sinc.set_ydata(x)
    
    # adjust the sinc plot height in a loop
    az1.set_ylim(np.min(F), np.max(F))
    
    plt.setp(ax1, xticks=[0, 100], xticklabels=['-1/4', '1/4'],
    yticks=[0, np.max(F)], yticklabels=['0', 'B={:.2f}'.format((B / length))])
    
    
    
def init():
    
    az1.set_xlim(0, 100)
    az1.set_ylim(-20, 20)
    az1.axhline(0, color='black', lw=1)
    plt.rcParams.update({'font.size':14})
    
    return sinc, 

# the FuncAnimation function iterates through our animate function using the steps array
step = 10
steps = np.append(np.arange(10, 1000, step), np.arange(1000, 10, -1 * step))
ani = FuncAnimation(fig, animate, steps, init_func=init, interval=50, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
